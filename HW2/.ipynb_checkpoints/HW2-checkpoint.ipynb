# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
to_grey=lambda x: cv2.cvtColor(x,cv2.COLOR_BGR2GRAY)
img=cv2.imread("group_5.jpg")
img=to_grey(img)
plt.figure(figsize=(10,15))
plt.imshow(img,cmap="gray")

# %%
# calc of x_bar_bar and s_bar
x_bar_bar=[]
s_bar=[]
for idx in range(400):
    row=img[idx]
    x_bar=row.mean()
    x_bar_bar.append(x_bar)
    s_=np.std(row,ddof=1)
    s_bar.append(s_)
x_bar_bar=np.mean(x_bar_bar)
s_bar=np.mean(s_bar)

# %%
# calc of a3,b3,b4
def calcs(n):
    c_4=(4*(n-1))/(4*n-3)
    a_3=3/(c_4*np.sqrt(n))
    b_3=1-3/(c_4*np.sqrt(2*(n-1)))
    b_4=1+3/(c_4*np.sqrt(2*(n-1)))
    return a_3,b_3,b_4
a_3,b_3,b_4=calcs(400)
x_ucl=x_bar_bar+a_3*s_bar
x_lcl=x_bar_bar-a_3*s_bar
s_ucl=b_4*s_bar
s_lcl=b_3*s_bar

# %%
img_controlled=[]
for i in range(400):
    row=img[i].copy()
    s_=np.std(row,ddof=1)
    if s_<s_ucl and s_>s_lcl:
        row=np.where((row<x_lcl)|(row>x_ucl),row,0)
    else:
        row=[0]*400
    img_controlled.append(row)
img_controlled=np.array(img_controlled)

# %%
#applying control
img_controlled_x=np.where((img<x_lcl)|(img>x_ucl),img,0)
fig,ax=plt.subplots(ncols=2,figsize=(20,15))
ax[0].imshow(img_controlled,cmap="gray")
ax[1].imshow(img,cmap="gray")

# %%
# calc of x_bar_bar and s_bar
x_bar_bar=[]
s_bar=[]
for idx in range(400):
    row=img[:,idx]
    x_bar=row.mean()
    x_bar_bar.append(x_bar)
    s_=np.std(row,ddof=1)
    s_bar.append(s_)
x_bar_bar=np.mean(x_bar_bar)
s_bar=np.mean(s_bar)

# %%
# calc of a3,b3,b4
def calcs(n):
    c_4=(4*(n-1))/(4*n-3)
    a_3=3/(c_4*np.sqrt(n))
    b_3=1-3/(c_4*np.sqrt(2*(n-1)))
    b_4=1+3/(c_4*np.sqrt(2*(n-1)))
    return a_3,b_3,b_4
a_3,b_3,b_4=calcs(400)
x_ucl=x_bar_bar+a_3*s_bar
x_lcl=x_bar_bar-a_3*s_bar
s_ucl=b_4*s_bar
s_lcl=b_3*s_bar

# %%
img_controlled=[]
for i in range(400):
    row=img[:,i].copy()
    s_=np.std(row,ddof=1)
    if s_<s_ucl and s_>s_lcl:
        row=np.where((row<x_lcl)|(row>x_ucl),row,0)
    else:
        row=[0]*400
    img_controlled.append(row)
img_controlled=np.array(img_controlled).T

# %%
#applying control
img_controlled_x=np.where((img<x_lcl)|(img>x_ucl),img,0)
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,15))
ax[0,0].imshow(img_controlled,cmap="gray")
ax[0,1].imshow(img,cmap="gray")
ax[1,0].imshow(img_controlled_x,cmap="gray")
ax[1,1].imshow(img,cmap="gray")

# %%
img_controlled_x,img
# Out:
# (array([[210, 210, 213, ..., 196, 197, 200],
#         [190, 185, 184, ..., 200, 203, 205],
#         [196, 196, 197, ..., 213, 213, 212],
#         ...,
#         [221, 213, 221, ..., 199, 201, 200],
#         [210, 205, 213, ..., 181, 176, 184],
#         [211, 205, 214, ..., 190, 195, 197]], dtype=uint8),
#  array([[210, 210, 213, ..., 196, 197, 200],
#         [190, 185, 184, ..., 200, 203, 205],
#         [196, 196, 197, ..., 213, 213, 212],
#         ...,
#         [221, 213, 221, ..., 199, 201, 200],
#         [210, 205, 213, ..., 181, 176, 184],
#         [211, 205, 214, ..., 190, 195, 197]], dtype=uint8))

# %%
vals,counts=np.unique(img[:,0],return_counts=True)
plt.figure(figsize=(15,10))
sns.barplot(x=vals,y=counts)
